# %%
def add(a, b):
    return a+b
print(add(3,4))
# Out:
# 7

# %%
def avg(a,b=10):
    return (a+b)/2

# %%
avg(4,6)
# Out:
# 5.0

# %%
avg(4)
# Out:
# 7.0

# %%
def greet():
    print("Hello good morning")

# %%
greet()
# Out:
# Hello good morning
