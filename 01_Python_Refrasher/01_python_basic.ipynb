# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Karnoze\Documents\Languages\Python\Courses\CWH-Data-Science\.venv\Scripts\python.exe

# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
name = "Ami"

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a = "4566"

# %%
b = "5677"

# %%
print(a + b)
# Out:
# 45665677

# %%
int(a) + int(b)   # type casting
# Out:
# 10243
