# %%
name = "Ammi"

# %%
name
# Out:
# 'Ammi'

# %%
name.upper()
# Out:
# 'AMMI'

# %%
name.endswith("i")
# Out:
# True

# %%
name.endswith("y")
# Out:
# False

# %%
name.lower()
# Out:
# 'ammi'

# %%
name.count("a")
# Out:
# 0

# %%
name.count("m")
# Out:
# 2

# %%
name.count("i")
# Out:
# 1

# %%
s = "AmiJohnson"
print(len(s))
# Out:
# 10

# %%
s[0:5]
# Out:
# 'AmiJo'

# %%
s[1:-1]
# Out:
# 'miJohnso'

# %%
s[1:]
# Out:
# 'miJohnson'

# %%
s[-9:-1]
# Out:
# 'miJohnso'

# %%
s[1:9]
# Out:
# 'miJohnso'
