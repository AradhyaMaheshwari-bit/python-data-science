# %% [markdown]
# A set in Python is an unordered, mutable, and unique collection of elements. It does not allow duplicate values.

# %% [markdown]
# ## Common Set Methods
#
# | Method | Description | Example |
# |--------|-------------|---------|
# | `add(x)` | Adds an element `x` to the set. | `my_set.add(10)` |
# | `update(iterable)` | Adds multiple elements from an iterable. | `my_set.update([6, 7, 8])` |
# | `remove(x)` | Removes `x` from the set. Raises a `KeyError` if `x` is not found. | `my_set.remove(3)` |
# | `discard(x)` | Removes `x` from the set. Does **not** raise an error if `x` is not found. | `my_set.discard(3)` |
# | `pop()` | Removes and returns an arbitrary element from the set. | `my_set.pop()` |
# | `clear()` | Removes all elements from the set. | `my_set.clear()` |
# | `copy()` | Returns a shallow copy of the set. | `new_set = my_set.copy()` |
#
# ## Set Operations
#
# | Operation | Description | Example |
# |-----------|-------------|---------|
# | `union(set2)` | Returns a new set containing all unique elements from both sets. | `set1.union(set2)` |
# | `intersection(set2)` | Returns a new set containing elements common to both sets. | `set1.intersection(set2)` |
# | `difference(set2)` | Returns a new set containing elements in `set1` but not in `set2`. | `set1.difference(set2)` |
# | `symmetric_difference(set2)` | Returns a new set containing elements that are in either set, but not in both. | `set1.symmetric_difference(set2)` |
# | `issubset(set2)` | Returns `True` if `set1` is a subset of `set2`. | `set1.issubset(set2)` |
# | `issuperset(set2)` | Returns `True` if `set1` is a superset of `set2`. | `set1.issuperset(set2)` |

# %%
empty_set = set()
# empty_set = {}

# %%
type(empty_set)

# %%
s = {4, 5, 7, 521, 98}

# %%
s

# %%
# Creating a set from a list
unique_numbers = set([1, 2, 2, 3, 4, 4, 5])
print(unique_numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {4, 5, 7, 521, 98}

# %%
s.add(34)

# %%
s
# Out:
# {4, 5, 7, 34, 98, 521}

# %%
s.update([4, 64, 33, 34])

# %%
s
# Out:
# {4, 5, 7, 33, 34, 64, 98, 521}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set2.union(set1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1
# Out:
# {1, 2, 3, 4}

# %%
set2
# Out:
# {3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
set2.intersection(set1)
# Out:
# {3, 4}

# %%
set1
# Out:
# {1, 2, 3, 4}

# %%
set2
# Out:
# {3, 4, 5, 6}

# %%
set1.difference(set2)
# Out:
# {1, 2}

# %%
set2.difference(set1)
# Out:
# {5, 6}

# %%
set1.symmetric_difference(set2)
# Out:
# {1, 2, 5, 6}

# %%
set2.symmetric_difference(set1)
# Out:
# {1, 2, 5, 6}

# %%
set1.issubset(set2)
# Out:
# False

# %%
sub = {1, 3}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True
