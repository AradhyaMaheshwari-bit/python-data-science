# %% [markdown]
# A dictionary in Python is an unordered, mutable, and key-value pair collection. It allows efficient data retrieval and modification. Dictionaries in Python are ordered as of Python 3.7

# %% [markdown]
# ## Common Dictionary Methods
#
# | Method | Description | Example |
# |--------|-------------|---------|
# | `keys()` | Returns a view of all keys in the dictionary. | `student.keys()` |
# | `values()` | Returns a view of all values in the dictionary. | `student.values()` |
# | `items()` | Returns a view of all key-value pairs as tuples. | `student.items()` |
# | `get(key, default)` | Returns the value for `key`, or `default` if the key is not found. | `student.get("age", 0)` |
# | `update(dict2)` | Updates the dictionary with key-value pairs from another dictionary or iterable. | `student.update({"age": 26})` |
# | `pop(key, default)` | Removes the specified key and returns its value. Returns `default` if provided and the key is not found. | `student.pop("grade")` |
# | `popitem()` | Removes and returns the last inserted key-value pair as a tuple. | `student.popitem()` |
# | `setdefault(key, default)` | Returns the value of `key` if it exists; otherwise, inserts `key` with `default` and returns `default`. | `student.setdefault("city", "Unknown")` |
# | `clear()` | Removes all key-value pairs from the dictionary. | `student.clear()` |
# | `copy()` | Returns a shallow copy of the dictionary. | `new_dict = student.copy()` |

# %%
empty_dict = {}

# %%
type(empty_dict)
# Out:
# dict

# %%
student = {
    "name": "Alice",
    "age": 25,
    "grade": "A"
}

# %%
student["name"]
# Out:
# 'John'

# %%
r = student.get("name")

# %%
s = student.get("name4")

# %%
print(r)
print(s)
# Out:
# John
# None

# %%
student["name"] = "John"

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['John', 25, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'John'), ('age', 25), ('grade', 'A')])

# %%
student.update({"name": "Ami"})

# %%
student
# Out:
# {'name': 'Ami', 'age': 25, 'grade': 'A'}

# %%
student.update({"name": "Ami", "language": "python"})

# %%
student
# Out:
# {'name': 'Ami', 'age': 25, 'grade': 'A', 'language': 'python'}

# %%
# Creating a dictionary using comprehension
squares = {x: x**2 for x in range(1, 6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
