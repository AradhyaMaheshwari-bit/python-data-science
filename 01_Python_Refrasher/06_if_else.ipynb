# %%
a = 4

# %%
if(a>53):
    print("Greater")
else:
    print(("Smaller"))
# Out:
# Smaller

# %%
a = 31
if a>50:
    print("greater than 50")
elif a>40:
    print("greater than 40")
if a>30:
    print("greater than 30")
else:
    print("smaller")
# Out:
# greater than 30
